# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitu-im/eda-lab-experiment/blob/exp-2_14_07_2026/exp_2_14_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("employee_salary.csv")

# %%
print("task-1\n")
# Out:
# task-1

# %%
print("the first 5 columns of the data frame are:\n")
df.head()
# Out:
# the first 5 columns of the data frame are:
#    EmployeeID    Name Department   Age  Experience   Salary  Gender       City
# 0         348   Lucas      Sales  53.0         7.0  52893.0  Female     Mumbai
# 1         340  Sophia  Marketing  53.0        15.0  70727.0    Male    Chennai
# 2         171   James         HR  40.0         6.0  62442.0    Male  Bengaluru
# 3         237   James    Finance  54.0        13.0  83865.0  Female  Hyderabad
# 4         488   James      Sales  24.0         3.0  50436.0  Female      Delhi

# %%
print("the last 5 columns of the data frame are:\n")
df.tail()
# Out:
# the last 5 columns of the data frame are:
#     EmployeeID    Name Department   Age  Experience   Salary  Gender  \
# 33         420    Isla    Finance  38.0        15.0  82703.0    Male
# 34         240  Olivia    Finance  59.0        20.0  82817.0    Male
# 35         546   Grace      Sales  46.0        25.0  77769.0  Female
# 36         386  Sophia         IT  30.0         9.0  67684.0    Male
# 37         559    Liam  Marketing  59.0         5.0      NaN  Female
#
#          City
# 33       Pune
# 34    Chennai
# 35  Hyderabad
# 36     Mumbai
# 37  Bengaluru

# %%
print("the shape of the data frame is:\n")
print(df.shape)
# Out:
# the shape of the data frame is:
#
# (38, 8)

# %%
print("the rows of the data frame are:\n")
print(df.shape[0])
# Out:
# the rows of the data frame are:
#
# 38

# %%
print("the columns of the data frame are:\n")
print(df.shape[1])
# Out:
# the columns of the data frame are:
#
# 8

# %%
print("task-2\n")
# Out:
# task-2

# %%
print("the column names of the data frame are:\n")
print(df.columns)
# Out:
# the column names of the data frame are:
#
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Experience', 'Salary',
#        'Gender', 'City'],
#       dtype='object')

# %%
print("the data types of the columns are:\n")
df.dtypes
# Out:
# the data types of the columns are:
# EmployeeID      int64
# Name           object
# Department     object
# Age           float64
# Experience    float64
# Salary        float64
# Gender         object
# City           object
# dtype: object

# %%
print("the data set information of the data frame are:\n")
print(df.info())
# Out:
# the data set information of the data frame are:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  38 non-null     int64
#  1   Name        38 non-null     object
#  2   Department  38 non-null     object
#  3   Age         37 non-null     float64
#  4   Experience  37 non-null     float64
#  5   Salary      36 non-null     float64
#  6   Gender      38 non-null     object
#  7   City        38 non-null     object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 2.5+ KB
# None

# %%
print("the summary statistics of the data frame are:\n")
df.describe()
# Out:
# the summary statistics of the data frame are:
#        EmployeeID        Age  Experience        Salary
# count   38.000000  37.000000   37.000000     36.000000
# mean   379.421053  40.432432    9.270270  62649.666667
# std    122.630103  12.070489    6.673533  13321.306184
# min    140.000000  22.000000    0.000000  45178.000000
# 25%    335.750000  30.000000    4.000000  52363.000000
# 50%    384.000000  38.000000    7.000000  59188.000000
# 75%    457.000000  53.000000   14.000000  70611.500000
# max    559.000000  59.000000   26.000000  97645.000000

# %%
print("task-3\n")
# Out:
# task-3

# %%
missing_counts = df.isnull().sum()
missing_pct = (missing_counts / len(df) * 100).round(2)
missing_summary = pd.DataFrame({
    "Missing Count": missing_counts,
    "Missing %": missing_pct
})
missing_summary = missing_summary[missing_summary["Missing Count"] > 0]
missing_counts = df.isnull().sum()
missing_percent = 100 * missing_counts / len(df)
missing_summary = pd.concat([missing_counts, missing_percent], axis=1)
missing_summary.columns = ["Missing Count", "Missing Percent"]
missing_summary = missing_summary[missing_summary["Missing Count"] > 0].sort_values("Missing Count", ascending=False)

# %%
print("\nColumns with missing values:")
print(missing_summary if not missing_summary.empty else "None")
# Out:
# Columns with missing values:
#             Missing Count  Missing Percent
# Salary                  2         5.263158
# Age                     1         2.631579
# Experience              1         2.631579

# %%
print(f"\nTotal missing cells in dataset: {missing_counts.sum()}")
dup_count = df.duplicated().sum()
# Out:
# Total missing cells in dataset: 4

# %%
print(f"\nNumber of Duplicate Records: {dup_count}")
size_before = df.shape[0]
df_clean = df.drop_duplicates()
size_after = df_clean.shape[0]
# Out:
# Number of Duplicate Records: 0

# %%
print(f"Dataset Size Before Cleaning: {size_before}")
# Out:
# Dataset Size Before Cleaning: 38

# %%
print(f"Dataset Size After Cleaning : {size_after}")
# Out:
# Dataset Size After Cleaning : 38

# %%
df_clean.to_csv("employee_salary_cleaned.csv", index=False)

# %%
print("\nCleaned dataset saved as employee_salary_cleaned.csv")
# Out:
# Cleaned dataset saved as employee_salary_cleaned.csv
