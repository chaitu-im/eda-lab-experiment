# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitu-im/eda-lab-experiment/blob/exp-6_18.08.2026/eda_lab6_18_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/WineQT.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
print(df.head(3))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2

# %%
print(df.tail(3))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
print(df.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
pd.isna(df).any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# Id                      False
# dtype: bool

# %%
df['quality'].astype(str).str.isnumeric().value_counts()
# Out:
# quality
# True    1143
# Name: count, dtype: int64

# %%
df['quality'].loc[df['quality'].astype(str).str.isnumeric() == False]
# Out:
# Series([], Name: quality, dtype: int64)

# %%
price = df['quality'].loc[df['quality'] != '?']
print(price)
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
pmean = price.astype(int).mean()
print("Mean =",pmean)
# Out:
# Mean = 5.657042869641295

# %%
df['price'] = price
df['price'].head(10)
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# 5    5
# 6    5
# 7    7
# 8    7
# 9    5
# Name: price, dtype: int64

# %%
ph = df['pH']
phmean = ph.astype(float).mean()
df['pH'] = df['pH'].replace('?', phmean).astype(float)
df['pH'].head()
# Out:
# 0    3.51
# 1    3.20
# 2    3.26
# 3    3.16
# 4    3.51
# Name: pH, dtype: float64

# %%
vamean = df['volatile acidity'].astype(float).mean()
df['volatile acidity'] = df['volatile acidity'].replace('?', vamean).astype(float)
print(f"Mean of 'volatile acidity': {vamean}")
# Out:
# Mean of 'volatile acidity': 0.5313385826771653

# %%
df['volatile acidity'].head()
# Out:
# 0    0.70
# 1    0.88
# 2    0.76
# 3    0.28
# 4    0.70
# Name: volatile acidity, dtype: float64

# %%
mean_density = df["density"].mean()
median_density = df["density"].median()
mode_density = df["density"].mode()
print(f"Mean of density: {mean_density}")
print(f"Median of density: {median_density}")
print(f"Mode of density: {mode_density}")
# Out:
# Mean of density: 0.9967304111986001
# Median of density: 0.99668
# Mode of density: 0    0.9976
# Name: density, dtype: float64

# %%
fig = plt.figure(figsize=(10, 6))
sns.histplot(df['density'], kde=True, bins=20)
plt.title('Distribution of Density in Wine Samples')
plt.xlabel('Density Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
sns.FacetGrid(df).map(sns.kdeplot, "pH").add_legend()

# %%
sns.FacetGrid(df).map(sns.histplot, "price", kde=True).add_legend()

# %%
sns.boxplot(x="price",data=df)
plt.show()

# %%
plt.scatter(df["alcohol"], df["price"])
plt.title("Scatter Plot for Alcohol vs Price")
plt.xlabel("Alcohol Content")
plt.ylabel("Price (Quality)")
plt.show()

# %%
sns.boxplot(x="price", y="alcohol", data=df)
plt.title("Boxplot of Quality (Price) vs Alcohol")
plt.show()

# %%
sns.boxplot(x="price", y="density", data=df)
plt.title("Boxplot of Quality (Price) vs Density")
plt.show()

# %%
sns.pairplot(df, vars=['alcohol', 'density', 'price'], kind="reg")
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, height=2, vars=['fixed acidity', 'volatile acidity', 'citric acid'], hue="price")
plt.show()

# %%
from scipy import stats
corr = stats.pearsonr(df["price"], df["alcohol"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 1.9246528151001656e-68
# cor:		 0.4848662118085117

# %%
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
# price                      0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.171831   0.107889            -0.164831
# volatile acidity           -0.005751   0.056336            -0.001962
# citric acid                 0.175815   0.245312            -0.057589
# residual sugar              1.000000   0.070863             0.165339
# chlorides                   0.070863   1.000000             0.015280
# free sulfur dioxide         0.165339   0.015280             1.000000
# total sulfur dioxide        0.190790   0.048163             0.661093
# density                     0.380147   0.208901            -0.054150
# pH                         -0.116959  -0.277759             0.072804
# sulphates                   0.017475   0.374784             0.034445
# alcohol                     0.058421  -0.229917            -0.047095
# quality                     0.022002  -0.124085            -0.063260
# Id                         -0.046344  -0.088099             0.095268
# price                       0.022002  -0.124085            -0.063260
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.110628  0.681501 -0.685163   0.174592
# volatile acidity                  0.077748  0.016512  0.221492  -0.276079
# citric acid                       0.036871  0.375243 -0.546339   0.331232
# residual sugar                    0.190790  0.380147 -0.116959   0.017475
# chlorides                         0.048163  0.208901 -0.277759   0.374784
# free sulfur dioxide               0.661093 -0.054150  0.072804   0.034445
# total sulfur dioxide              1.000000  0.050175 -0.059126   0.026894
# density                           0.050175  1.000000 -0.352775   0.143139
# pH                               -0.059126 -0.352775  1.000000  -0.185499
# sulphates                         0.026894  0.143139 -0.185499   1.000000
# alcohol                          -0.188165 -0.494727  0.225322   0.094421
# quality                          -0.183339 -0.175208 -0.052453   0.257710
# Id                               -0.107389 -0.363926  0.132904  -0.103954
# price                            -0.183339 -0.175208 -0.052453   0.257710
#
#                        alcohol   quality        Id     price
# fixed acidity        -0.075055  0.121970 -0.275826  0.121970
# volatile acidity     -0.203909 -0.407394 -0.007892 -0.407394
# citric acid           0.106250  0.240821 -0.139011  0.240821
# residual sugar        0.058421  0.022002 -0.046344  0.022002
# chlorides            -0.229917 -0.124085 -0.088099 -0.124085
# free sulfur dioxide  -0.047095 -0.063260  0.095268 -0.063260
# total sulfur dioxide -0.188165 -0.183339 -0.107389 -0.183339
# density              -0.494727 -0.175208 -0.363926 -0.175208
# pH                    0.225322 -0.052453  0.132904 -0.052453
# sulphates             0.094421  0.257710 -0.103954  0.257710
# alcohol               1.000000  0.484866  0.238087  0.484866
# quality               0.484866  1.000000  0.069708  1.000000
# Id                    0.238087  0.069708  1.000000  0.069708
# price                 0.484866  1.000000  0.069708  1.000000

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns)
plt.show()
